# %%
import pandas as pd
import json
pd.options.mode.chained_assignment = None

# %%
submission_df = pd.read_csv("api_submission.csv")
submission_df
# Out:
#                                         submission_code  \
# 0                               print("Hello World!")\n
# 1                                                   NaN
# 2                               print("Hello World!")\n
# 3                               print("Hello World!")\n
# 4                                print("Hello World")\n
# ...                                                 ...
# 2185  #include <stdio.h>\r\n\r\nint main() {\r\n    ...
# 2186  #include <stdio.h>\r\n\r\nint main() {\r\n    ...
# 2187  #include <stdio.h>\r\n\r\nint main() {\r\n    ...
# 2188  #include <stdio.h>\r\n\r\nint main() {\r\n    ...
# 2189  #include <stdio.h>\r\n\r\nint main() {\r\n    ...
#
#                             date  is_passed  account_id  \
# 0     2022-10-27 07:16:02.229668          1           5
# 1     2022-10-27 07:16:16.675488          0           5
# 2     2022-10-27 07:16:19.502776          1           5
# 3     2022-10-27 07:17:19.152737          1           5
# 4     2022-11-13 11:56:38.030682          0           4
# ...                          ...        ...         ...
# 2185  2024-01-14 13:27:12.822191          0          14
# 2186  2024-01-15 20:43:13.728600          0           4
# 2187  2024-01-15 20:43:26.187614          0           4
# 2188  2024-01-15 20:44:00.234384          0           4
# 2189  2024-01-15 20:45:14.611504          1           4
#
#                             problem_id  max_score  passed_ratio  score  \
# 0                                   26          0           0.0      0
# 1                                   26          0           0.0      0
# 2                                   26          0           0.0      0
# 3                                   26          0           0.0      0
# 4                                   26          0           0.0      0
# ...                                ...        ...           ...    ...
# 2185  466254a3a6ac4bc8b7ee9e0925d2ba86         10           0.2      2
# 2186  466254a3a6ac4bc8b7ee9e0925d2ba86         10           0.0      0
# 2187  466254a3a6ac4bc8b7ee9e0925d2ba86         10           0.0      0
# 2188  466254a3a6ac4bc8b7ee9e0925d2ba86         10           0.2      2
# 2189  466254a3a6ac4bc8b7ee9e0925d2ba86         10           1.0     10
#
#      language                          topic_id  \
# 0      python                               NaN
# 1      python                               NaN
# 2      python                               NaN
# 3      python                               NaN
# 4      python                               NaN
# ...       ...                               ...
# 2185        c  538b9db3e2a04c94974c54526115f844
# 2186        c  538b9db3e2a04c94974c54526115f844
# 2187        c  538b9db3e2a04c94974c54526115f844
# 2188        c  538b9db3e2a04c94974c54526115f844
# 2189        c  538b9db3e2a04c94974c54526115f844
#
#                          submission_id
# 0                                  160
# 1                                  161
# 2                                  162
# 3                                  163
# 4                                  182
# ...                                ...
# 2185  243658b154a34bb9bb87268400bf25a5
# 2186  de692bd7b9374bc9a2346fae8ec92a9e
# 2187  cd39f2e6d58c4fb396507752804e3a1c
# 2188  88d691f7b6714c61a1c127fe28eee1e8
# 2189  46bd9779f6b74f5fbe5968ec54452797
#
# [2190 rows x 11 columns]

# %%
submission_df = submission_df[['account_id', 'problem_id','is_passed','language','date','submission_code','passed_ratio']]

# Change submission_code to string
submission_df['submission_code'] = submission_df['submission_code'].astype(str)
submission_df
# Out:
#       account_id                        problem_id  is_passed language  \
# 0              5                                26          1   python
# 1              5                                26          0   python
# 2              5                                26          1   python
# 3              5                                26          1   python
# 4              4                                26          0   python
# ...          ...                               ...        ...      ...
# 2185          14  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2186           4  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2187           4  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2188           4  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2189           4  466254a3a6ac4bc8b7ee9e0925d2ba86          1        c
#
#                             date  \
# 0     2022-10-27 07:16:02.229668
# 1     2022-10-27 07:16:16.675488
# 2     2022-10-27 07:16:19.502776
# 3     2022-10-27 07:17:19.152737
# 4     2022-11-13 11:56:38.030682
# ...                          ...
# 2185  2024-01-14 13:27:12.822191
# 2186  2024-01-15 20:43:13.728600
# 2187  2024-01-15 20:43:26.187614
# 2188  2024-01-15 20:44:00.234384
# 2189  2024-01-15 20:45:14.611504
#
#                                         submission_code  passed_ratio
# 0                               print("Hello World!")\n           0.0
# 1                                                   nan           0.0
# 2                               print("Hello World!")\n           0.0
# 3                               print("Hello World!")\n           0.0
# 4                                print("Hello World")\n           0.0
# ...                                                 ...           ...
# 2185  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.2
# 2186  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.0
# 2187  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.0
# 2188  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.2
# 2189  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           1.0
#
# [2190 rows x 7 columns]

# %%
# Sort by account_id, problem_id and date
submission_df.sort_values(['account_id','problem_id','date'])

# Calculate the difference time between the current submission and the previous submission
submission_df['date'] = pd.to_datetime(submission_df['date'])
submission_df['diff_time'] = submission_df.groupby(['account_id','problem_id'])['date'].diff()
submission_df['diff_time'] = submission_df['diff_time'].dt.total_seconds()

# Set all diff_time which is NaN to 0
submission_df['diff_time'].fillna(0, inplace=True)

# Set all diff_time which has more than 3 hours to 3
submission_df.loc[submission_df['diff_time'] > 10800, 'diff_time'] = 10801
submission_df
# Out:
#       account_id                        problem_id  is_passed language  \
# 0              5                                26          1   python
# 1              5                                26          0   python
# 2              5                                26          1   python
# 3              5                                26          1   python
# 4              4                                26          0   python
# ...          ...                               ...        ...      ...
# 2185          14  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2186           4  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2187           4  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2188           4  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2189           4  466254a3a6ac4bc8b7ee9e0925d2ba86          1        c
#
#                            date  \
# 0    2022-10-27 07:16:02.229668
# 1    2022-10-27 07:16:16.675488
# 2    2022-10-27 07:16:19.502776
# 3    2022-10-27 07:17:19.152737
# 4    2022-11-13 11:56:38.030682
# ...                         ...
# 2185 2024-01-14 13:27:12.822191
# 2186 2024-01-15 20:43:13.728600
# 2187 2024-01-15 20:43:26.187614
# 2188 2024-01-15 20:44:00.234384
# 2189 2024-01-15 20:45:14.611504
#
#                                         submission_code  passed_ratio  \
# 0                               print("Hello World!")\n           0.0
# 1                                                   nan           0.0
# 2                               print("Hello World!")\n           0.0
# 3                               print("Hello World!")\n           0.0
# 4                                print("Hello World")\n           0.0
# ...                                                 ...           ...
# 2185  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.2
# 2186  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.0
# 2187  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.0
# 2188  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.2
# 2189  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           1.0
#
#       diff_time
# 0      0.000000
# 1     14.445820
# 2      2.827288
# 3     59.649961
# 4      0.000000
# ...         ...
# 2185   8.971618
# 2186   0.000000
# 2187  12.459014
# 2188  34.046770
# 2189  74.377120
#
# [2190 rows x 8 columns]

# %%
# Loop each row
current_problem_id = None
current_account_id = None
already_passed = False
previous_diff_time = -1


for index, row in submission_df.iterrows():
    if not current_problem_id and not current_account_id:
        current_problem_id = row['problem_id']
        current_account_id = row['account_id']

    if current_problem_id != row['problem_id'] or current_account_id != row['account_id']:
        current_problem_id = row['problem_id']
        current_account_id = row['account_id']
        already_passed = False
    elif already_passed:
        # row['diff_time'] = 0
        submission_df.drop(index, inplace=True)
    elif row['is_passed'] == 1:
        already_passed = True
        if row['diff_time'] > 10800:
            row['diff_time'] = previous_diff_time

submission_df
# Out:
#       account_id                        problem_id  is_passed language  \
# 0              5                                26          1   python
# 4              4                                26          0   python
# 5              4                                26          0   python
# 6              4                                26          1   python
# 7              4                                33          1   python
# ...          ...                               ...        ...      ...
# 2185          14  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2186           4  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2187           4  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2188           4  466254a3a6ac4bc8b7ee9e0925d2ba86          0        c
# 2189           4  466254a3a6ac4bc8b7ee9e0925d2ba86          1        c
#
#                            date  \
# 0    2022-10-27 07:16:02.229668
# 4    2022-11-13 11:56:38.030682
# 5    2022-11-13 11:56:38.753475
# 6    2022-11-13 11:56:43.121230
# 7    2022-11-14 07:35:00.337364
# ...                         ...
# 2185 2024-01-14 13:27:12.822191
# 2186 2024-01-15 20:43:13.728600
# 2187 2024-01-15 20:43:26.187614
# 2188 2024-01-15 20:44:00.234384
# 2189 2024-01-15 20:45:14.611504
#
#                                         submission_code  passed_ratio  \
# 0                               print("Hello World!")\n           0.0
# 4                                print("Hello World")\n           0.0
# 5                                print("Hello World")\n           0.0
# 6                               print("Hello World!")\n           0.0
# 7     text = input("Input text: ")\ncol = int(input(...           0.0
# ...                                                 ...           ...
# 2185  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.2
# 2186  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.0
# 2187  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.0
# 2188  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           0.2
# 2189  #include <stdio.h>\r\n\r\nint main() {\r\n    ...           1.0
#
#       diff_time
# 0      0.000000
# 4      0.000000
# 5      0.722793
# 6      4.367755
# 7      0.000000
# ...         ...
# 2185   8.971618
# 2186   0.000000
# 2187  12.459014
# 2188  34.046770
# 2189  74.377120
#
# [2137 rows x 8 columns]

# %%
grouped_submission_df = submission_df.groupby(['account_id','problem_id']).agg({'is_passed':'sum','date':'count','diff_time':'sum'}).reset_index()

# Rename columns
grouped_submission_df.rename(columns={'date':'first_passed_total_attempts','is_passed':'passed_submission'}, inplace=True)


grouped_submission_df
# Out:
#      account_id problem_id  passed_submission  first_passed_total_attempts  \
# 0             4        101                  1                            1
# 1             4        102                  1                           14
# 2             4        103                  3                            3
# 3             4        111                  0                            1
# 4             4        113                  0                            2
# ..          ...        ...                ...                          ...
# 537          34         90                  1                            5
# 538          34         91                  0                            8
# 539          35         39                  1                            8
# 540          37         39                  1                           15
# 541          37         89                  1                           10
#
#         diff_time
# 0        0.000000
# 1    27306.114982
# 2     3875.544723
# 3        0.000000
# 4    10801.000000
# ..            ...
# 537  14344.738131
# 538  12335.630535
# 539    591.711660
# 540    429.970366
# 541   1544.946604
#
# [542 rows x 5 columns]

# %%
grouped_submission_df = grouped_submission_df.groupby(['problem_id']).agg({'passed_submission':'sum','first_passed_total_attempts':'sum','diff_time':'mean'}).reset_index()

grouped_submission_df['first_pf_ratio'] = grouped_submission_df['passed_submission'] / grouped_submission_df['first_passed_total_attempts']
df = grouped_submission_df.drop(['passed_submission','first_passed_total_attempts'], axis=1)

# Change problem_id to index
df.set_index('problem_id', inplace=True)
df
# Out:
#                                     diff_time  first_pf_ratio
# problem_id
# 100                               4909.323282        0.250000
# 101                                339.843212        0.428571
# 102                               7609.605477        0.148148
# 103                               1504.160602        0.454545
# 104                               2221.719998        0.700000
# ...                                       ...             ...
# 96                                 128.579397        0.400000
# 97                                 685.743135        0.189189
# 98                                  33.388133        0.470588
# 99                                  66.590902        0.500000
# c16b270c3efd4ae4b9278400f64fdc15    10.102029        0.400000
#
# [117 rows x 2 columns]

# %%
difficulty = json.load(open('difficulty.json'))

def applyDifficulty(row):
    return difficulty[str(row.name)]

df['difficulty'] = df.apply(applyDifficulty, axis=1)
df
# Out:
#                                     diff_time  first_pf_ratio  difficulty
# problem_id
# 100                               4909.323282        0.250000           1
# 101                                339.843212        0.428571           1
# 102                               7609.605477        0.148148           2
# 103                               1504.160602        0.454545           1
# 104                               2221.719998        0.700000           1
# ...                                       ...             ...         ...
# 96                                 128.579397        0.400000           1
# 97                                 685.743135        0.189189           1
# 98                                  33.388133        0.470588           1
# 99                                  66.590902        0.500000           1
# c16b270c3efd4ae4b9278400f64fdc15    10.102029        0.400000           1
#
# [117 rows x 3 columns]

# %%
df.to_csv('modelgrader_submission_processed.csv')
print("Done")
# Out:
# Done
